# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrimota/FaculProjects/blob/main/OCR_Tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !sudo apt-get install -y tesseract-ocr-por
# !pip install pillow
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-por
# 0 upgraded, 1 newly installed, 0 to remove and 1 not upgraded.
# Need to get 856 kB of archives.
# After this operation, 1,998 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-por all 1:4.00~git30-7274cfa-1.1 [856 kB]
# Fetched 856 kB in 0s (8,707 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# ...

# %%
# !tesseract --list-langs
# Out:
# List of available languages (3):
# eng
# osd
# por

# %%
# Importar bibliotecas necessárias
import pytesseract
from PIL import Image
import requests
from io import BytesIO

# imagem de exemplo
img = '/content/Captura_tela4.png'

# Executar OCR na imagem
texto = pytesseract.image_to_string(img, lang='por')

# Exibir o texto extraído
print(texto)
# Out:
# Tem gente que gostaria de ter a sua vida, que daria
# tudo para passar polos perrenques que você passa o
# acha que não vai suportar. Gente que não tem muita
# escolha mas continua seguindo em frente. Não pode
# parar. Gente que queria ter um dia do seu conforto,
# fazer uma das suas viagens. Gente que tem
# qualidade, mas não tem tanta oportunidade, Gente
# que fecha os olhos e agradece por estar vivo. Por
# sobreviver. E você segue ai, reclamando dessa sua
# vida difícil. Um problema vira uma tempestade, a falta
# de um telefonema vira uma inimizade. A verdade é
# que as pessoas têm realidades diferentes, mas o que
# importa mesmo é coma lidam com elas. Se vivem
# reclamando, ou se fazem funcionar à vida que têm.
# Alinni Zorzi teistasersadasecrtas
