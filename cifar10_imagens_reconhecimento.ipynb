# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrimota/FaculProjects/blob/main/cifar10_imagens_reconhecimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Carregar os dados CIFAR-10
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Pré-processamento das imagens
train_images = train_images / 255.0
test_images = test_images / 255.0

# Definir o modelo CNN
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compilar o modelo
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Treinar o modelo
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Avaliar o modelo
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 50ms/step - accuracy: 0.4678 - loss: 1.4637 - val_accuracy: 0.5848 - val_loss: 1.1618
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 47ms/step - accuracy: 0.6202 - loss: 1.0713 - val_accuracy: 0.6245 - val_loss: 1.0661
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 47ms/step - accuracy: 0.6797 - loss: 0.9053 - val_accuracy: 0.6817 - val_loss: 0.9267
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 47ms/step - accuracy: 0.7241 - loss: 0.7810 - val_accuracy: 0.6973 - val_loss: 0.8947
# Epoch 5/10
# ...

# %%
model.save('modelo_cifar10.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image

# Carregar o modelo treinado
model = tf.keras.models.load_model('modelo_cifar10.h5')

# Carregar uma nova imagem
image_path = '/content/dados/'  # Substitua pelo caminho da sua imagem
img = image.load_img(image_path, target_size=(32, 32))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalização

# Fazer a previsão
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)

# Mapear o número da classe para o nome da classe
class_names = ['avião', 'automóvel', 'pássaro', 'gato', 'cervo', 'cachorro', 'sapo', 'cavalo', 'navio', 'caminhão']
predicted_label = class_names[predicted_class]

print('Predicted class:', predicted_label)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /tmp/ipykernel_30692/462331673.py in <cell line: 0>()
#       8 # Carregar uma nova imagem
#       9 image_path = '/content/dados/'  # Substitua pelo caminho da sua imagem
# ---> 10 img = image.load_img(image_path, target_size=(32, 32))
#      11 img_array = image.img_to_array(img)
#      12 img_array = np.expand_dims(img_array, axis=0)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_utils.py in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     245         if isinstance(path, pathlib.Path):
#     246             path = str(path.resolve())
# --> 247         with open(path, "rb") as f:
# ...

# %%
import os
import shutil

# criar pasta dados
os.makedirs('/content/dados', exist_ok=True)

# mover imagens para a pasta dados
arquivos = os.listdir('/content')

for arquivo in arquivos:

    if arquivo.endswith(('.jpg', '.jpeg', '.png')):

        origem = f'/content/{arquivo}'
        destino = f'/content/dados/{arquivo}'

        shutil.move(origem, destino)

print('Imagens movidas para /content/dados/')
# Out:
# Imagens movidas para /content/dados/

# %%
for nome in os.listdir('/content/dados'):

    caminho = '/content/dados/' + nome

    img = image.load_img(caminho, target_size=(32, 32))

    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    previsao = model.predict(img_array, verbose=0)
    classe = np.argmax(previsao)

    print(nome, '->', class_names[classe])
# Out:
# download (17).jpg -> automóvel
# download (3).jpg -> gato
# download (11).jpg -> cachorro
# download (7).jpg -> cavalo
# download (10).jpg -> cachorro
# download (9).jpg -> cachorro
# download (5).jpg -> cachorro
# download (4).jpg -> cachorro
# download (16).jpg -> caminhão
# treino.jpg -> avião
# download (1).jpg -> sapo
# download (13).jpg -> cachorro
# download (15).jpg -> cachorro
# download (14).jpg -> cachorro
# download (12).jpg -> cachorro
# download (2).jpg -> automóvel
# download (8).jpg -> gato
# download.jpg -> avião
# download (19).jpg -> automóvel
# download (20).jpg -> caminhão
# download (6).jpg -> sapo
# download (18).jpg -> automóvel

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_30692/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...
